# %%
# %matplotlib inline

from matplotlib import pyplot
from matplotlib.patches import Rectangle

data = pyplot.imread('African_Bush_Elephant.jpg')

pyplot.imshow(data)

ax = pyplot.gca()

rect = Rectangle((74, 241), 495, 713, fill=False, color='black')
#rect1 = Rectangle((90, 495), 629, 221, fill=False, color='black')
#rect2 = Rectangle((308, 119), 250, 163, fill=False, color='white')
ax.add_patch(rect)
#ax.add_patch(rect1)
#ax.add_patch(rect2)

v_labels = ['elephant']
#v_labels = ['car', 'car']
#v_labels = ['zebra', 'zebra', 'zebra']
#v_labels = ['cat']
v_scores = [99.60509538650513]
#v_scores = [99.82818365097046, 93.60970854759216, 97.3427951335907]
#v_scores = [99.22417402267456]
for i in range(len(v_labels)):
    label = "%s (%.3f)" % (v_labels[i], v_scores[i])
    pyplot.text(74, 241, label, color='black')
    #pyplot.text(90, 495, label, color='black')
    #pyplot.text(308, 119, label, color='white')

pyplot.show()
